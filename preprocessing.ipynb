# %%
import pandas as pd
from datetime import datetime
import json

# %%
# Load the dataset
data = pd.read_csv('./data/kc_house_data.csv')

# %%
data.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Convert date into timestamp
#data["timestamp"] = data.apply(lambda x: datetime.strptime(x['date'][:8], '%Y%m%d').timestamp(), axis=1).astype('int64')
data = data.sort_values(by=['date'])
data = data.reset_index(drop=True)
data["timestamp"] = data.index

# %%
# Enum type must be string
data["id"] = data["id"].astype(str)
data["date"] = data.apply(lambda x: x['date'][:8], axis=1).astype('int64')
# data["zipcode"] = data["zipcode"].astype(str)
# data["waterfront"] = data["waterfront"].astype(str)
# data["view"] = data["view"].astype(str)
# data["condition"] = data["condition"].astype(str)


# Convert in craft ai python dictionnary structure
context_list = []
for index, row in data.iterrows():
    context_list.append({
        "timestamp" : row["timestamp"],
        "context" : {
#           "id": row["id"],
            "date": row["date"],
            "price": row["price"],
            "bedrooms": row["bedrooms"],
            "bathrooms": row["bathrooms"],
            "sqft_living": row["sqft_living"],
            "sqft_lot": row["sqft_lot"],
            "floors": row["floors"],
            "waterfront": row["waterfront"],
            "view": row["view"],
            "condition": row["condition"],
            "grade": row["grade"],
            "sqft_above": row["sqft_above"],
            "sqft_basement": row["sqft_basement"],
            "yr_built": row["yr_built"],
            "yr_renovated": row["yr_renovated"],
            "zipcode": row["zipcode"],
            "lat": row["lat"],
            "long": row["long"],
            "sqft_living15": row["sqft_living15"],
            "sqft_lot15": row["sqft_lot15"]
        }
    })

# Output
with open('./data/clean_data.json', 'w') as outfile:
    json.dump(context_list, outfile, indent = 3)
print("Saved to ./data/clean_data.json")
# Out:
# Saved to ./clean_data.json

# %%
context_list
# Out:
# [{'timestamp': 0,
#   'context': {'date': 20140502,
#    'price': 437500.0,
#    'bedrooms': 3,
#    'bathrooms': 2.25,
#    'sqft_living': 1970,
#    'sqft_lot': 35100,
#    'floors': 2.0,
#    'waterfront': 0,
#    'view': 0,
#    'condition': 4,
#    'grade': 9,
#    'sqft_above': 1970,
#    'sqft_basement': 0,
#    'yr_built': 1977,
#    'yr_renovated': 0,
#    'zipcode': 98027,
#    'lat': 47.4635,
#    'long': -121.991,
#    'sqft_living15': 2340,
#    'sqft_lot15': 35100}},
#  {'timestamp': 1,
#   'context': {'date': 20140502,
#    'price': 790000.0,
#    'bedrooms': 3,
#    'bathrooms': 2.5,
#    'sqft_living': 2600,
#    'sqft_lot': 4750,
#    'floors': 1.0,
#    'waterfront': 0,
#    'view': 0,
#    'condition': 4,
#    'grade': 9,
#    'sqft_above': 1700,
#    'sqft_basement': 900,
#    'yr_built': 1951,
#    'yr_renovated': 0,
#    'zipcode': 98117,
#    'lat': 47.6833,
#    'long': -122.4,
#    'sqft_living15': 2380,
#    'sqft_lot15': 4750}},
#  {'timestamp': 2,
# ...
